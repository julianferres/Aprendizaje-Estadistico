# %%
# %matplotlib inline

# %% [markdown]
# # Simulación para SVM con distintos kernels

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, svm , metrics
import seaborn as sns

# %%
# Import the dataset using Seaborn library
iris=pd.read_csv('iris.csv')
# Checking the dataset
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Creating a pairplot to visualize the similarities and especially difference between the species
sns.pairplot(data=iris, hue='species', palette='Set2');

# %%
#Create training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(iris.iloc[:,:4], iris['species'], test_size=0.3, random_state=0) 
print (X_train.shape, y_train.shape) 
print (X_test.shape, y_test.shape) 

#Let us try and fit our classifier to the training set!

#Using SVM classifier 
clf = svm.SVC(kernel='linear', C=1).fit(X_train, y_train) 
print(clf.score(X_test, y_test))
# Out:
# (105, 4) (105,)
# (45, 4) (45,)
# 0.9777777777777777

# %%
expected = y_test
predicted = clf.predict(X_test)

print("Reporte de nuestro clasificador %s:\n%s\n"
      % (clf, metrics.classification_report(expected, predicted)))
print("Matriz de confusión:\n%s" % metrics.confusion_matrix(expected, predicted))
# Out:
# Reporte de nuestro clasificador SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False):
#              precision    recall  f1-score   support
#
#      setosa       1.00      1.00      1.00        16
#  versicolor       1.00      0.94      0.97        18
#   virginica       0.92      1.00      0.96        11
#
# avg / total       0.98      0.98      0.98        45
#
#
# Matriz de confusión:
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]
