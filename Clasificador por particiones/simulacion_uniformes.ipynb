# %% [markdown]
# ## Simulador de Uniformes con soporte en Regiones de $\mathbb{R}^2$

# %% [markdown]
# ### Julian Ferres - Nro.Padrón 101483

# %% [markdown]
# ## Enunciado

# %% [markdown]
# Simular $n$ puntos las distribuciones uniformes con soporte en las regiones $R_0$ y $R_1$ , donde:
#
# - $R_0$ es el triangulo con vertices $(1,0)$, $(1,1)$ y $(\frac{1}{2},0)$
# - $R_1$ es el triangulo con vertices $(0,0)$, $(\frac{1}{2},1)$ y $(0,1)$
#
# - $n = 10, 100, 1000, 10000, \ldots$

# %% [markdown]
# ## Solución

# %%
#Import libraries
import numpy as np
#Plots
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
n = 1000 #Tamaño de muestra

# %% [markdown]
# #### Simulación de la distribucion uniforme con soporte en $R_0$

# %%
y1 = np.random.uniform( 0, 1, n ) #Uniforme continua sobre (0,1)

x1 = np.zeros((n,))
for i in range(n):
    x1[i] = np.random.uniform((1-y1[i])/2 ,(1+y1[i])/2)

# %% [markdown]
# #### Simulación de la distribucion uniforme con soporte en $R_1$

# %%
y2 = np.random.uniform( 0, 1, n )

x2 = np.zeros((n,))

for i in range(n):
    x2[i] = np.random.uniform( y2[i]/2 , 1 - y2[i]/2)

# %% [markdown]
# #### Grafico las muestras

# %%
g = plt.scatter( x1 , y1 , alpha='0.5', color='green', label = 'Clase 0');
g = plt.scatter( x2 , y2 , alpha='0.5', color='orange', label = 'Clase 1');
plt.legend();
plt.title("Distribuciones", fontsize=20)
# Out:
# Text(0.5,1,'Distribuciones')

# %% [markdown]
# Link al Repo de GitHub: https://github.com/julianferres/Aprendizaje-Estadistico.git
